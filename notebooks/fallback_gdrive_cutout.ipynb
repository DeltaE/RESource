# %%
from RESource.utility import load_config, get_gdrive_public_file

# %%
gdrv_cfg=load_config("credentials/gdrive.yaml")

# %%
target_file="BC_2024.nc"

# %%
get_gdrive_public_file(gdrv_cfg[f'{target_file}'], target_file)
# Out:
# Skipping downloading from Google Drive. Expected file found locally at: BC_2024.nc
